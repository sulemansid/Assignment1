# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_excel('Data_Science_2020_v2.xlsx')
df.head()
# Out:
#   Application_ID Current City  Python (out of 3)  R Programming (out of 3)  \
# 0         DS0001    Bangalore                  1                         0
# 1         DS0002       Mumbai                  2                         1
# 2         DS0003       Mumbai                  2                         0
# 3         DS0004      Dhanbad                  2                         0
# 4         DS0005    Bangalore                  2                         0
#
#    Data Science (out of 3)                                       Other skills  \
# 0                        3  Machine Learning, Arduino, C Programming, CSS,...
# 1                        2  AutoCAD, MS-Office, Machine Learning, Microsof...
# 2                        0  C++ Programming, Data Structures, Image Proces...
# 3                        2  Algorithms, C++ Programming, Data Structures, ...
# 4                        0                     MS-Word, Python, SQL, MS-Excel
#
# ...

# %%
df.isnull().sum()
# Out:
# Application_ID                  0
# Current City                    0
# Python (out of 3)               0
# R Programming (out of 3)        0
# Data Science (out of 3)         0
# Other skills                   10
# Institute                       0
# Degree                         36
# Stream                         31
# Current Year Of Graduation      0
# Performance_PG                483
# Performance_UG                 78
# Performance_12                248
# Performance_10                272
# dtype: int64

# %%
df1=df.drop(['Application_ID','Current City','Institute','Stream','Performance_PG','Performance_UG','Performance_12','Performance_10'],axis=1)
df1
# Out:
#      Python (out of 3)  R Programming (out of 3)  Data Science (out of 3)  \
# 0                    1                         0                        3
# 1                    2                         1                        2
# 2                    2                         0                        0
# 3                    2                         0                        2
# 4                    2                         0                        0
# ..                 ...                       ...                      ...
# 606                  2                         2                        2
# 607                  1                         0                        0
# 608                  2                         2                        0
# 609                  3                         2                        2
# 610                  2                         2                        0
#
#                                           Other skills  \
# ...

# %%
df1.shape
# Out:
# (611, 6)

# %%
df.shape
# Out:
# (611, 14)

# %%
df1.Degree.unique()
# Out:
# array(['Bachelor of Engineering (B.E)', nan,
#        'Bachelor of Technology (B.Tech)', 'Integrated M.Tech',
#        'B.Tech (Hons.)', 'Master of Business Administration_(MBA)', 'MBA',
#        'Master of Science (M.Sc)', 'Post Graduate Programme (PGP)',
#        'Master of Computer Applications (MCA)',
#        'Bachelor of Pharmacy (B.Pharm)', 'Integrated MCA',
#        'Bachelor of Commerce (B.Com)', 'Master of Technology (M.Tech)',
#        'Integrated B.Sc. & M.Sc.', 'Post Graduate Diploma',
#        'Integrated M.Sc.', 'Master of Arts (M.A.)',
#        'PG Diploma in Data Science', 'Bachelor of Science (B.Sc)',
#        'Integrated B.Tech', 'Master of Statistics (M.Stat)',
#        'Post Graduate Diploma in Management (P.G.D.M.)',
#        'Master of Engineering (M.E)', 'Master Of Analytics',
#        'Bachelor of Computer Applications (BCA)',
#        'Integrated B.S. & M.S.', 'Bachelor of Science (B.Sc) (Hons.)',
#        'Bachelor of Computer Science (B.C.S.)',
# ...

# %%
df2=df1.copy()

# %%
df2
# Out:
#      Python (out of 3)  R Programming (out of 3)  Data Science (out of 3)  \
# 0                    1                         0                        3
# 1                    2                         1                        2
# 2                    2                         0                        0
# 3                    2                         0                        2
# 4                    2                         0                        0
# ..                 ...                       ...                      ...
# 606                  2                         2                        2
# 607                  1                         0                        0
# 608                  2                         2                        0
# 609                  3                         2                        2
# 610                  2                         2                        0
#
#                                           Other skills  \
# ...

# %%
df2['Degree']=df1['Degree'].replace(to_replace=['Bachelor of Engineering (B.E)', 'Bachelor of Technology (B.Tech)','B.Tech (Hons.)',
                                      'Bachelor of Science (B.Sc)','Bachelor of Science (B.Sc) (Hons.)','Bachelor of Computer Science (B.C.S.)',
                                      'Bachelor of Mathematics (B.Math) (Hons.)','Bachelor of Engineering (B.E) (Hons.)','Bachelor of Business Management (B.B.M.)',
                                      'Bachelor of Commerce (B.Com) (Hons.)','Bachelor of Business Administration (B.B.A.)','Bachelor of Pharmacy (B.Pharm)'
                                     'Bachelor of Commerce (B.Com)','Bachelor of Computer Applications (BCA)','Integrated B.Tech','B.Com. Professional','Bachelor of Pharmacy (B.Pharm)','Bachelor of Commerce (B.Com)'],value='UG')

# %%
df2
# Out:
#      Python (out of 3)  R Programming (out of 3)  Data Science (out of 3)  \
# 0                    1                         0                        3
# 1                    2                         1                        2
# 2                    2                         0                        0
# 3                    2                         0                        2
# 4                    2                         0                        0
# ..                 ...                       ...                      ...
# 606                  2                         2                        2
# 607                  1                         0                        0
# 608                  2                         2                        0
# 609                  3                         2                        2
# 610                  2                         2                        0
#
#                                           Other skills  \
# ...

# %%
df2['Degree']=df2['Degree'].replace(to_replace=['Integrated M.Tech',
       'Master of Business Administration_(MBA)', 'MBA',
       'Master of Science (M.Sc)', 'Post Graduate Programme (PGP)',
       'Master of Computer Applications (MCA)', 'Integrated MCA',
       'Master of Technology (M.Tech)', 'Integrated B.Sc. & M.Sc.',
       'Post Graduate Diploma', 'Integrated M.Sc.',
       'Master of Arts (M.A.)', 'PG Diploma in Data Science',
       'Master of Statistics (M.Stat)',
       'Post Graduate Diploma in Management (P.G.D.M.)',
       'Master of Engineering (M.E)', 'Master Of Analytics',
       'Integrated B.S. & M.S.', 'Master of Science (M.S.)',
       'Master of Science (M.Sc) (Hons.)', 'Integrated B.Tech & M.Tech',
       'Integrated B.Tech & MBA',
       'Post Graduate Diploma in Business Management (P.G.D.B.M.)',
       'Executive MBA',
       'Post Graduate Diploma in Big Data Analytics (PG-DBDA)',
       'Post Graduate Program in Business Analytics'],value='PG')

# %%
df2
# Out:
#      Python (out of 3)  R Programming (out of 3)  Data Science (out of 3)  \
# 0                    1                         0                        3
# 1                    2                         1                        2
# 2                    2                         0                        0
# 3                    2                         0                        2
# 4                    2                         0                        0
# ..                 ...                       ...                      ...
# 606                  2                         2                        2
# 607                  1                         0                        0
# 608                  2                         2                        0
# 609                  3                         2                        2
# 610                  2                         2                        0
#
#                                           Other skills Degree  \
# ...

# %%
df3=df2.copy()

# %%
df3.Degree.unique()
# Out:
# array(['UG', nan, 'PG'], dtype=object)

# %%
df3[['Python (out of 3)','R Programming (out of 3)','Data Science (out of 3)']][(df3["Degree"]=='UG' )& (df3["Current Year Of Graduation"]==2020)]
# Out:
#      Python (out of 3)  R Programming (out of 3)  Data Science (out of 3)
# 21                   2                         0                        0
# 24                   3                         0                        2
# 33                   1                         0                        0
# 52                   3                         0                        2
# 88                   0                         0                        0
# 98                   2                         2                        2
# 131                  2                         0                        0
# 171                  2                         2                        2
# 180                  2                         0                        0
# 185                  2                         2                        2
# 186                  3                         2                        2
# 206                  2                         0                        2
# ...

# %%
df3['Python (out of 3)'].unique()
# Out:
# array([1, 2, 0, 3], dtype=int64)

# %%
df3.loc[df3['Python (out of 3)']==3,'Python (out of 3)']=10
df3.loc[df3['Python (out of 3)']==2,'Python (out of 3)']=7
df3.loc[df3['Python (out of 3)']==1,'Python (out of 3)']=3
df3.loc[df3['Python (out of 3)']==0,'Python (out of 3)']=0

# %%
df3.loc[df3['R Programming (out of 3)']==3,'R Programming (out of 3)']=10
df3.loc[df3['R Programming (out of 3)']==2,'R Programming (out of 3)']=7
df3.loc[df3['R Programming (out of 3)']==1,'R Programming (out of 3)']=3
df3.loc[df3['R Programming (out of 3)']==0,'R Programming (out of 3)']=0

# %%
df3.loc[df3['Data Science (out of 3)']==3,'Data Science (out of 3)']=10
df3.loc[df3['Data Science (out of 3)']==2,'Data Science (out of 3)']=7
df3.loc[df3['Data Science (out of 3)']==1,'Data Science (out of 3)']=3
df3.loc[df3['Data Science (out of 3)']==0,'Data Science (out of 3)']=0

# %%
df3.head()
# Out:
#    Python (out of 3)  R Programming (out of 3)  Data Science (out of 3)  \
# 0                  3                         0                       10
# 1                  7                         3                        7
# 2                  7                         0                        0
# 3                  7                         0                        7
# 4                  7                         0                        0
#
#                                         Other skills Degree  \
# 0  Machine Learning, Arduino, C Programming, CSS,...     UG
# 1  AutoCAD, MS-Office, Machine Learning, Microsof...    NaN
# 2  C++ Programming, Data Structures, Image Proces...     UG
# 3  Algorithms, C++ Programming, Data Structures, ...     PG
# 4                     MS-Word, Python, SQL, MS-Excel     UG
#
#    Current Year Of Graduation
# 0                        2019
# 1                        2020
# 2                        2018
# 3                        2021
# ...

# %%
df4=df3.copy()

# %%
df4
# Out:
#      Python (out of 3)  R Programming (out of 3)  Data Science (out of 3)  \
# 0                    3                         0                       10
# 1                    7                         3                        7
# 2                    7                         0                        0
# 3                    7                         0                        7
# 4                    7                         0                        0
# ..                 ...                       ...                      ...
# 606                  7                         7                        7
# 607                  3                         0                        0
# 608                  7                         7                        0
# 609                 10                         7                        7
# 610                  7                         7                        0
#
#                                           Other skills Degree  \
# ...

# %%
df5=df4.dropna(how='any',axis=0)
df6=df5.reset_index(drop=True)

# %%
df6
# Out:
#      Python (out of 3)  R Programming (out of 3)  Data Science (out of 3)  \
# 0                    3                         0                       10
# 1                    7                         0                        0
# 2                    7                         0                        7
# 3                    7                         0                        0
# 4                    7                         7                        0
# ..                 ...                       ...                      ...
# 560                  7                         7                        7
# 561                  3                         0                        0
# 562                  7                         7                        0
# 563                 10                         7                        7
# 564                  7                         7                        0
#
#                                           Other skills Degree  \
# ...

# %%
df6.loc[(df6['Degree']=='UG') & (df6['Current Year Of Graduation']>=2020),'Grad_points']= 10
df6.loc[(df6['Degree']=='UG') & (df6['Current Year Of Graduation']==2019),'Grad_points']= 8
df6.loc[(df6['Degree']=='UG') & (df6['Current Year Of Graduation']<=2018),'Grad_points']= 5
df6.loc[(df6['Degree']=='PG') & (df6['Current Year Of Graduation']>=2020),'Grad_points']= 7
df6.loc[(df6['Degree']=='PG') & (df6['Current Year Of Graduation']<=2019),'Grad_points']= 3

# %%
df6.tail()
# Out:
#      Python (out of 3)  R Programming (out of 3)  Data Science (out of 3)  \
# 560                  7                         7                        7
# 561                  3                         0                        0
# 562                  7                         7                        0
# 563                 10                         7                        7
# 564                  7                         7                        0
#
#                                           Other skills Degree  \
# 560  AutoCAD, MS-Excel, Deep Learning, Machine Lear...     UG
# 561                        MS-Excel, HTML, Python, SQL     PG
# 562  Data Analytics, Machine Learning, Natural Lang...     UG
# 563  Data Analytics, Machine Learning, Python, C Pr...     UG
# 564  Computer Vision, Data Analytics, Image Process...     PG
#
#      Current Year Of Graduation  Grad_points
# 560                        2020         10.0
# 561                        2020          7.0
# ...

# %%
df7=df6.rename(columns={'Python (out of 3)': 'Python_score', 'R Programming (out of 3)': 'R_score',
                    'Data Science (out of 3)':'DS_score','Other skills':'Other_skills',
                   'Current Year Of Graduation':'Current_Year_Of_Graduation'
                   })

# %%
df7
# Out:
#      Python_score  R_score  DS_score  \
# 0               3        0        10
# 1               7        0         0
# 2               7        0         7
# 3               7        0         0
# 4               7        7         0
# ..            ...      ...       ...
# 560             7        7         7
# 561             3        0         0
# 562             7        7         0
# 563            10        7         7
# 564             7        7         0
#
#                                           Other_skills Degree  \
# 0    Machine Learning, Arduino, C Programming, CSS,...     UG
# 1    C++ Programming, Data Structures, Image Proces...     UG
# 2    Algorithms, C++ Programming, Data Structures, ...     PG
# 3                       MS-Word, Python, SQL, MS-Excel     UG
# 4    C Programming, C++ Programming, CSS, GitHub, H...     UG
# ..                                                 ...    ...
# 560  AutoCAD, MS-Excel, Deep Learning, Machine Lear...     UG
# ...

# %%
df8=df7['Python_score']+df7['R_score']+df7['DS_score']+df7['Grad_points']

# %%
df7['Other_skills']=='NLP'
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 560    False
# 561    False
# 562    False
# 563    False
# 564    False
# Name: Other_skills, Length: 565, dtype: bool

# %%
df7['Other_skills'].dtypes
# Out:
# dtype('O')
